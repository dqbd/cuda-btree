# %%
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib

matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %%
# 100k
insert_100k = (16995.179000)
find_100k = (72.388000)


host_insert_1m = (781.845000, 632.903000, 610.523000, 517.571000, 515.030000, 473.749000, 470.748000, 447.199000, 443.430000, 416.976000, 415.406000, 398.864000, 391.373000, 386.704000, 382.733000, 382.877000, 379.121000, 380.095000, 373.956000, 394.236000, 367.117000, 379.999000, 360.639000, 355.477000, 347.853000, 350.263000, 343.400000, 344.422000, 343.881000)

host_find_1m = (632.242000, 485.755000, 468.932000, 416.897000, 419.472000, 393.970000, 389.286000, 368.168000, 381.687000, 343.844000, 361.306000, 343.604000, 355.776000, 342.542000, 349.219000, 329.254000, 321.622000, 322.174000, 319.949000, 319.795000, 320.379000, 317.205000, 317.982000, 317.638000, 299.744000, 312.002000, 299.662000, 309.485000, 301.435000)

cuda_insert_1m = (117.445885, 98.135422, 80.855873, 74.307587, 67.286621, 65.244995, 64.594627, 63.698078, 62.567265, 62.899361, 62.032448, 62.152802, 61.332577, 61.813854, 62.991135, 63.480095, 64.245728, 64.544289, 65.131203, 65.048355, 66.189438, 66.695969, 67.845757, 68.315010, 69.738914, 70.287651, 71.375710, 71.227615, 71.292259)

cuda_find_1m = (2.157952, 1.782560, 1.195136, 0.971072, 0.920352, 0.904256, 0.803360, 0.754464, 0.715648, 0.723744, 0.677696, 0.654272, 0.634880, 0.640096, 0.611968, 0.591136, 0.600704, 0.602048, 0.579808, 0.555424, 0.569472, 0.557760, 0.551552, 0.535808, 0.543680, 0.544320, 0.543584, 0.514560, 0.529696)


order_host = pd.DataFrame(data=(host_insert_1m, host_find_1m), index=["Insert (Host)", "Find (Host)"], columns=range(4, 32 + 1)).transpose()
order_cuda = pd.DataFrame(data=(cuda_insert_1m, cuda_find_1m), index=["Insert (Cuda)", "Find (Cuda)"], columns=range(4, 32 + 1)).transpose()

host_ax = order_host.plot(xlabel="Order", ylabel="Insertion time (in ms)", figsize=(12, 8))
cuda_ax = order_cuda.plot(xlabel="Order", ylabel="Insertion time (in ms)", figsize=(12, 8), grid=True, ax=host_ax)

cuda_ax.set_xticks(range(4, 32 + 1))

# %%
display(order_host["Insert (Host)"][16] / order_cuda["Insert (Cuda)"][16])
display(order_host["Find (Host)"][16] / order_cuda["Find (Cuda)"][16])
# Out:
# 6.381160211154995
# 560.383064516129

# %%
order_host.plot(xlabel="Order", ylabel="Insertion time (in ms)", figsize=(12, 8), grid=True).set_xticks(range(4, 32 + 1));

# %%
order_cuda["Insert (Cuda)"].plot(xlabel="Order", ylabel="Insertion time (in ms)", figsize=(12, 8), grid=True).set_xticks(range(4, 32 + 1));

# %%
order_cuda["Insert (Cuda)"].idxmin()
# Out:
# 16

# %%
columns = [
    "power",
    "increasing",
    "decreasing",
    "shuffle",
    "almostSorted",
]

# %% [markdown]
# # BTree::Cuda::v4

# %%
btree_cuda_v4_insert = (
    (10,0.5849,0.5589,0.5364,0.6021),
# %% [markdown]
# # BTree::Host

# %%
btree_host_insert = (
    (10,0.0495,0.1220,0.1465,0.0781),
    (11,0.0900,0.1720,0.2458,0.0700),
    (12,0.1480,0.2744,0.4264,0.1493),
    (13,0.3142,0.5635,0.9154,0.3179),
    (14,0.6788,1.1565,1.9140,0.6675),
    (15,1.3183,2.3741,4.1188,1.3186),
    (16,2.8074,4.7946,8.9167,2.8228),
    (17,5.6686,9.4882,19.3075,6.1727),
    (18,11.7459,18.7978,42.4778,12.5257),
    (19,24.8245,38.6087,105.3057,26.2313),
    (20,53.8363,82.4116,272.5388,52.1090),
    (21,121.4649,170.8097,676.1957,122.2067),
    (22,229.3672,339.2268,1617.8210,241.0609),
    (23,489.1167,679.3893,3698.7037,481.8787),
    (24,980.4123,1377.9834,8409.5210,987.4019),
    (25,2077.1400,2845.3220,19068.9930,2128.9320),
)

btree_host_query = (
    (10,0.0510,0.0600,0.0850,0.0560),
    (11,0.1230,0.1010,0.1650,0.0950),
    (12,0.2250,0.2050,0.3660,0.1950),
    (13,0.4260,0.4370,0.7760,0.4260),
    (14,0.8460,0.8870,1.7020,0.8730),
    (15,1.7100,1.7920,3.7230,1.7720),
    (16,3.5540,3.7070,8.1710,3.5610),
    (17,7.3210,7.8640,17.7930,7.5510),
    (18,14.9670,16.2210,41.8860,14.8790),
    (19,31.1400,33.1570,117.9900,30.9420),
    (20,63.4630,67.7830,317.8360,62.9520),
    (21,133.1390,142.3740,826.3150,131.0320),
    (22,272.4060,296.7000,1778.1050,276.5230),
    (23,553.0950,581.3100,4095.1130,552.3970),
    (24,1157.0550,1208.6740,9290.9980,1139.9220),
    (25,2336.6940,2452.1960,22028.9460,2369.0070),
)

# %% [markdown]
# # Comparisons

# %%
insert_dfs = {
    "btree_cuda_v4": pd.DataFrame(data=btree_cuda_v4_insert, columns=columns).set_index("power"),
    "btree_cuda_v7": pd.DataFrame(data=btree_cuda_v7_insert, columns=columns).set_index("power"),
    "owg": pd.DataFrame(data=owg_insert, columns=columns).set_index("power"),
    "stx": pd.DataFrame(data=stx_insert, columns=columns).set_index("power"),
    "tlx": pd.DataFrame(data=tlx_insert, columns=columns).set_index("power"),
    "stl": pd.DataFrame(data=stl_insert, columns=columns).set_index("power"),
    "btree_host": pd.DataFrame(data=btree_host_insert, columns=columns).set_index("power"),
}

query_dfs = {
    "btree_cuda_v4": pd.DataFrame(data=btree_cuda_v4_query, columns=columns).set_index("power"),
    "btree_cuda_v7": pd.DataFrame(data=btree_cuda_v7_query, columns=columns).set_index("power"),
    "owg": pd.DataFrame(data=owg_query, columns=columns).set_index("power"),
    "stx": pd.DataFrame(data=stx_query, columns=columns).set_index("power"),
    "tlx": pd.DataFrame(data=tlx_query, columns=columns).set_index("power"),
    "stl": pd.DataFrame(data=stl_query, columns=columns).set_index("power"),
    "btree_host": pd.DataFrame(data=btree_host_query, columns=columns).set_index("power"),
}

# %%
plot = pd.DataFrame(...).plot()
fig = plot.get_figure()
fig.savefig("lol.pgf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-04653d3480e5> in <module>
# ----> 1 plot = pd.DataFrame(...).plot()
#       2 fig = plot.get_figure()
#       3 fig.savefig("lol.pgf")
#       4
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     588         else:
#     589             if index is None or columns is None:
# --> 590                 raise ValueError("DataFrame constructor not properly called!")
#     591
#     592             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %% [markdown]
# ## Insert speed-up comparison
#
# Using random shuffling, everage of 10 runs

# %%
print(pd.concat([
    insert_dfs["stl"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["tlx"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["stx"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["btree_host"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["owg"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["btree_cuda_v7"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["btree_cuda_v7"]["shuffle"] / insert_dfs["owg"]["shuffle"],
], axis=1, keys=["stl", "tlx", "stx", "tnl:host", "owg", "tnl:cuda", "gpu"]).to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# {} &        stl &        tlx &        stx &   tnl:host &       owg &  tnl:cuda &       gpu \\
# power &            &            &            &            &           &           &           \\
# \midrule
# 10    &   0.559785 &   0.361928 &   0.301890 &   0.356094 &  0.537909 &       1.0 &  1.859051 \\
# 11    &   0.366543 &   0.499634 &   0.523098 &   0.484649 &  0.534534 &       1.0 &  1.870789 \\
# 12    &   0.675987 &   0.616360 &   0.377357 &   0.708208 &  0.526838 &       1.0 &  1.898118 \\
# 13    &   1.261728 &   1.154552 &   0.701039 &   1.297737 &  0.488388 &       1.0 &  2.047553 \\
# 14    &   2.867381 &   2.529908 &   1.554492 &   2.734649 &  0.800535 &       1.0 &  1.249165 \\
# 15    &   4.696714 &   3.851036 &   2.372735 &   4.149113 &  0.729530 &       1.0 &  1.370746 \\
# 16    &   6.819055 &   5.548523 &   3.293827 &   5.712464 &  0.617008 &       1.0 &  1.620725 \\
# ...

# %% [markdown]
# ## Query speedup comparison
#
# Using random shuffling, average of 10 runs

# %%
print(pd.concat([
    query_dfs["stl"]["shuffle"] / query_dfs["btree_cuda_v7"]["shuffle"],
    query_dfs["tlx"]["shuffle"] / query_dfs["btree_cuda_v7"]["shuffle"],
    query_dfs["stx"]["shuffle"] / query_dfs["btree_cuda_v7"]["shuffle"],
    query_dfs["btree_host"]["shuffle"] / query_dfs["btree_cuda_v7"]["shuffle"],
    query_dfs["owg"]["shuffle"] / query_dfs["btree_cuda_v7"]["shuffle"],
    query_dfs["btree_cuda_v7"]["shuffle"] / query_dfs["btree_cuda_v7"]["shuffle"],
    query_dfs["btree_cuda_v7"]["shuffle"] / query_dfs["owg"]["shuffle"],
], axis=1, keys=["stl", "tlx", "stx", "tnl:host", "owg", "tnl:cuda", "gpu"]).to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# {} &         stl &        tlx &        stx &   tnl:host &       owg &  tnl:cuda &       gpu \\
# power &             &            &            &            &           &           &           \\
# \midrule
# 10    &    1.756897 &   4.990890 &   1.164758 &   2.765487 &  1.447814 &       1.0 &  0.690697 \\
# 11    &    3.462238 &   3.430523 &   2.093200 &   4.360834 &  1.345251 &       1.0 &  0.743356 \\
# 12    &    6.913171 &   7.535356 &   4.340484 &   9.036502 &  1.160425 &       1.0 &  0.861753 \\
# 13    &   14.695619 &  15.093766 &   9.032102 &  17.357383 &  1.044574 &       1.0 &  0.957328 \\
# 14    &   28.302371 &  26.757939 &  16.607237 &  31.218818 &  0.981320 &       1.0 &  1.019036 \\
# 15    &   38.538902 &  34.756553 &  20.231627 &  38.601111 &  1.239010 &       1.0 &  0.807096 \\
# 16    &   40.546494 &  33.700787 &  20.797244 &  38.296775 &  1.029715 &       1.0 &  0.971142 \\
# ...

# %%
idx = 2 ** insert_dfs["stl"].index.to_series()
# Out:
# power
# 10        1024
# 11        2048
# 12        4096
# 13        8192
# 14       16384
# 15       32768
# 16       65536
# 17      131072
# 18      262144
# 19      524288
# 20     1048576
# 21     2097152
# 22     4194304
# 23     8388608
# 24    16777216
# 25    33554432
# Name: power, dtype: int64

# %%
query_plot_df = pd.concat([
    idx / query_dfs["stl"]["shuffle"],
    idx / query_dfs["tlx"]["shuffle"],
    idx / query_dfs["stx"]["shuffle"],
    idx / query_dfs["btree_host"]["shuffle"],
    idx / query_dfs["owg"]["shuffle"],
    idx / query_dfs["btree_cuda_v7"]["shuffle"],
], axis=1, keys=["stl", "tlx", "stx", "tnl:host", "owg", "tnl:cuda"])

query_plot_df.index = idx
query_plot = query_plot_df.plot(title="Rychlost vyhledávání", figsize=(12, 7), grid=True, logy=True, logx=True, style='.-')

query_plot.set_xlabel("Počet prvků")
query_plot.set_ylabel("Počet operací za sekundu")

query_plot.get_figure().savefig("speed.pgf")

# %%
insert_plot_df = pd.concat([
    idx / insert_dfs["stl"]["shuffle"],
    idx / insert_dfs["tlx"]["shuffle"],
    idx / insert_dfs["stx"]["shuffle"],
    idx / insert_dfs["btree_host"]["shuffle"],
    idx / insert_dfs["owg"]["shuffle"],
    idx / insert_dfs["btree_cuda_v7"]["shuffle"],
], axis=1, keys=["stl", "tlx", "stx", "tnl:host", "owg", "tnl:cuda"])

insert_plot_df.index = idx
insert_plot = insert_plot_df.plot(title="Rychlost vkládání", figsize=(12, 7), grid=True, logy=True, logx=True, style='.-')

insert_plot.set_xlabel("Počet prvků")
insert_plot.set_ylabel("Počet operací za sekundu")

insert_plot.get_figure().savefig("insert-speed.pgf")

# %%
speedup_tnl = pd.concat([
    insert_dfs["stl"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["tlx"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["stx"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["btree_host"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["owg"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
    insert_dfs["btree_cuda_v7"]["shuffle"] / insert_dfs["btree_cuda_v7"]["shuffle"],
], axis=1, keys=["stl", "tlx", "stx", "tnl:host", "owg", "tnl:cuda"])

display(speedup_tnl)
# Out:
#              stl        tlx        stx   tnl:host       owg  tnl:cuda
# power
# 10      0.559785   0.361928   0.301890   0.356094  0.537909       1.0
# 11      0.366543   0.499634   0.523098   0.484649  0.534534       1.0
# 12      0.675987   0.616360   0.377357   0.708208  0.526838       1.0
# 13      1.261728   1.154552   0.701039   1.297737  0.488388       1.0
# 14      2.867381   2.529908   1.554492   2.734649  0.800535       1.0
# 15      4.696714   3.851036   2.372735   4.149113  0.729530       1.0
# 16      6.819055   5.548523   3.293827   5.712464  0.617008       1.0
# 17      9.049610   6.642281   4.052213   7.177082  0.522869       1.0
# 18     12.562172   7.309113   4.669678   7.950461  0.459402       1.0
# 19     19.947893   8.082023   5.133084   9.581259  0.431834       1.0
# 20     27.513083   9.139274   6.294732  12.021791  0.410721       1.0
# 21     32.865620  10.537929   8.002906  14.104571  0.400988       1.0
# ...
